# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjukadam/project/blob/main/ANN_project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df=pd.read_csv("/content/diabetes.csv")

# %%
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
model=Sequential()
model.add(Dense(8,activation='relu',input_shape=(x_train.shape[1],)))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
prediction=model.fit(x_train,y_train,epochs=50,batch_size=32,validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6401 - loss: 0.6547 - val_accuracy: 0.6234 - val_loss: 0.6548
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6661 - loss: 0.6276 - val_accuracy: 0.6364 - val_loss: 0.6322
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6694 - loss: 0.6050 - val_accuracy: 0.6429 - val_loss: 0.6147
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6726 - loss: 0.5859 - val_accuracy: 0.6753 - val_loss: 0.6003
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6857 - loss: 0.5696 - val_accuracy: 0.6753 - val_loss: 0.5882
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6954 - loss: 0.5571 - val_accuracy: 0.6818 - val_loss: 0.5770
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6906 - loss: 0.5445 - val_accuracy: 0.6753 - val_loss: 0.5684
# Epoch 8/50
# ...

# %%
model.predict(x_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# array([[0.5099295 ],
#        [0.07418042],
#        [0.05827894],
#        [0.3783111 ],
#        [0.37795955],
#        [0.6721254 ],
#        [0.00414103],
#        [0.74171305],
#        [0.6744135 ],
#        [0.63341963],
#        [0.3224992 ],
#        [0.71944046],
#        [0.26708907],
#        [0.46685278],
#        [0.03920274],
#        [0.51411957],
#        [0.08353745],
#        [0.03591996],
#        [0.84162074],
#        [0.72388434],
#        [0.26687264],
#        [0.03254271],
#        [0.40973163],
#        [0.0235585 ],
#        [0.5836647 ],
#        [0.80403394],
#        [0.07349453],
#        [0.00968449],
#        [0.12902135],
#        [0.20305227],
#        [0.9123556 ],
#        [0.768594  ],
#        [0.7852443 ],
#        [0.8552302 ],
#        [0.6983314 ],
#        [0.6506758 ],
#        [0.906138  ],
#        [0.39487323],
#        [0.34594235],
#        [0.8123542 ],
#        [0.03947754],
# ...
